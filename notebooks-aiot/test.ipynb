# %% [markdown]
# # 필요 라이브러리 및 함수 정의

# %%
import redis
import time
import base64
import json
import csv
import random
import statistics

import numpy as np
import pandas as pd

# %%
def sliding_window(data, window_size, step):
    for start_row in range(0, len(data) - window_size + 1, step):
        yield data[start_row:start_row + window_size]

# %% [markdown]
# # 입력 데이터 정의

# %%
#file = input()

# %%
#test = pd.read_csv(file,header=None)

# %%
test = pd.read_csv("text_1.csv", header=None)
#test = pd.read_csv("text_2.csv", header=None)
test2 = pd.read_csv("text_3.csv", header=None)
test = test.transpose()
test2 = test2.transpose()
#test

# %%
test
# Out:
#                                                      0
# 0    b'{"ReceivedTopic":"","CorrelationID":"","Payl...
# 1    b'{"ReceivedTopic":"","CorrelationID":"","Payl...
# 2    b'{"ReceivedTopic":"","CorrelationID":"","Payl...
# 3    b'{"ReceivedTopic":"","CorrelationID":"","Payl...
# 4    b'{"ReceivedTopic":"","CorrelationID":"","Payl...
# ..                                                 ...
# 995  b'{"ReceivedTopic":"","CorrelationID":"","Payl...
# 996  b'{"ReceivedTopic":"","CorrelationID":"","Payl...
# 997  b'{"ReceivedTopic":"","CorrelationID":"","Payl...
# 998  b'{"ReceivedTopic":"","CorrelationID":"","Payl...
# 999  b'{"ReceivedTopic":"","CorrelationID":"","Payl...
#
# [1000 rows x 1 columns]

# %% [markdown]
# # 데이터 전처리

# %%
val = test.values[i][0]
val = val.replace("'", "")
val = val.replace("b","",1)
json_val = json.loads(val)
json_list.append(json_val)

res_payload = json_val['Payload']
dec_res = base64.b64decode(res_payload)
dec_res = dec_res.decode("UTF-8")
str_test = dec_res.replace("'","\"")
json_data = json.loads(str_test)

# %%
#차후 변수 동적처리
humid = []
pm10 = []
pm25 = []
temp = []
json_list = []

for i in range(len(test)):
    val = test.values[i][0]
    val = val.replace("'", "")
    val = val.replace("b","",1)
    json_val = json.loads(val)
    json_list.append(json_val)
    
    res_payload = json_val['Payload']
    dec_res = base64.b64decode(res_payload)
    dec_res = dec_res.decode("UTF-8")
    str_test = dec_res.replace("'","\"")
    json_data = json.loads(str_test)
    
    humid.append(json_data['event']['readings'][0]['objectValue']['humidity'])
    pm10.append(json_data['event']['readings'][0]['objectValue']['pm10'])
    pm25.append(json_data['event']['readings'][0]['objectValue']['pm25'])
    temp.append(json_data['event']['readings'][0]['objectValue']['temperature'])

# %%
#차후 변수 동적처리
humid = []
pm10 = []
pm25 = []
temp = []
json_list2 = []

for i in range(len(test2)):
    val = test2.values[i][0]
    val = val.replace("'", "")
    val = val.replace("b","",1)
    json_val = json.loads(val)
    json_list2.append(json_val)
    
    res_payload = json_val['Payload']
    dec_res = base64.b64decode(res_payload)
    dec_res = dec_res.decode("UTF-8")
    str_test = dec_res.replace("'","\"")
    json_data = json.loads(str_test)
    
    humid.append(json_data['event']['readings'][0]['objectValue']['humidity'])
    pm10.append(json_data['event']['readings'][0]['objectValue']['pm10'])
    pm25.append(json_data['event']['readings'][0]['objectValue']['pm25'])
    temp.append(json_data['event']['readings'][0]['objectValue']['temperature'])

# %%
len(json_list)
# Out:
# 1000

# %%
json_list
# Out:
# [{'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
# ...
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'},
#  {'ReceivedTopic': '',
#   'CorrelationID': '',
#   'Payload': '...',
#   'ContentType': 'application/json'}]

# %%
res_payload = json_list[9]["Payload"]
dec_res = base64.b64decode(res_payload)
dec_res = dec_res.decode("UTF-8")
str_test = dec_res.replace("'","\"")
json_data = json.loads(str_test)
json_data
# Out:
# {'apiVersion': 'v2',
#  'requestId': '3df31aa1-0df4-4d9b-ac83-54f5194df560',
#  'event': {'apiVersion': 'v2',
#   'id': 'be17a83f-bb6d-415a-a517-0922592358a9',
#   'deviceName': 'MD_08',
#   'profileName': 'MD-Device-MQTT-Profile',
#   'sourceName': 'MicrodustNodeStatus',
#   'origin': 1698804909767768887,
#   'readings': [{'id': '36e6ac8c-cfe6-4c6a-801b-ff5b3e027bde',
#     'origin': 1698804909767730174,
#     'deviceName': 'MD_08',
#     'resourceName': 'MicrodustNodeStatus',
#     'profileName': 'MD-Device-MQTT-Profile',
#     'valueType': 'Object',
#     'value': '',
#     'objectValue': {'device': {'data': [77, 68], 'type': 'Buffer'},
#      'device_id': '697d56637cc66b08',
#      'error': 0,
#      'humidity': 81,
#      'len': '45',
#      'msgid': {'data': [48, 50], 'type': 'Buffer'},
#      'pm10': 33,
#      'pm25': 16,
#      'seqnum': '0001',
#      'temperature': 19,
#      'timestamp': '231101111459'}}]}}

# %%
res_payload = json_list[999]["Payload"]
dec_res = base64.b64decode(res_payload)
dec_res = dec_res.decode("UTF-8")
str_test = dec_res.replace("'","\"")
json_data = json.loads(str_test)
json_data
# Out:
# {'apiVersion': 'v2',
#  'requestId': 'ba68089f-6842-4fb5-a37f-6c0095a893cf',
#  'event': {'apiVersion': 'v2',
#   'id': 'c94b872c-c419-4ec6-b097-3f0eed6b2390',
#   'deviceName': 'MD_08',
#   'profileName': 'MD-Device-MQTT-Profile',
#   'sourceName': 'MicrodustNodeStatus',
#   'origin': 1698805901264957289,
#   'readings': [{'id': '3a91c8dd-7037-4e34-9a05-b9d3b4856ef3',
#     'origin': 1698805901264919681,
#     'deviceName': 'MD_08',
#     'resourceName': 'MicrodustNodeStatus',
#     'profileName': 'MD-Device-MQTT-Profile',
#     'valueType': 'Object',
#     'value': '',
#     'objectValue': {'device': {'data': [77, 68], 'type': 'Buffer'},
#      'device_id': '697d56637cc66b08',
#      'error': 0,
#      'humidity': 85,
#      'len': '45',
#      'msgid': {'data': [48, 50], 'type': 'Buffer'},
#      'pm10': 30,
#      'pm25': 15,
#      'seqnum': '0001',
#      'temperature': 19.4,
#      'timestamp': '231101113130'}}]}}

# %%
res_payload = json_list[110]["Payload"]
dec_res = base64.b64decode(res_payload)
dec_res = dec_res.decode("UTF-8")
str_test = dec_res.replace("'","\"")
json_data = json.loads(str_test)
json_data
# Out:
# {'apiVersion': 'v2',
#  'requestId': '258deeeb-be14-4710-9b7d-03e2cd3ac7c0',
#  'event': {'apiVersion': 'v2',
#   'id': 'd4e2b28c-8c90-4170-8d5f-726d9f865e04',
#   'deviceName': 'MD_05',
#   'profileName': 'MD-Device-MQTT-Profile',
#   'sourceName': 'MicrodustNodeStatus',
#   'origin': 1698805019886513134,
#   'readings': [{'id': '9a3e41f6-60ee-44ab-8a88-7d3ab5d6837b',
#     'origin': 1698805019886458113,
#     'deviceName': 'MD_05',
#     'resourceName': 'MicrodustNodeStatus',
#     'profileName': 'MD-Device-MQTT-Profile',
#     'valueType': 'Object',
#     'value': '',
#     'objectValue': {'device': {'data': [77, 68], 'type': 'Buffer'},
#      'device_id': '56cb21c217805117',
#      'error': 0,
#      'humidity': 84,
#      'len': '45',
#      'msgid': {'data': [48, 50], 'type': 'Buffer'},
#      'pm10': 32,
#      'pm25': 16,
#      'seqnum': '0001',
#      'temperature': 19.3,
#      'timestamp': '231101111649'}}]}}

# %%
res_payload = json_list[200]["Payload"]
dec_res = base64.b64decode(res_payload)
dec_res = dec_res.decode("UTF-8")
str_test = dec_res.replace("'","\"")
json_data = json.loads(str_test)
json_data
# Out:
# {'apiVersion': 'v2',
#  'requestId': '34a7d920-e1ad-40fb-b804-b32c1a8f771d',
#  'event': {'apiVersion': 'v2',
#   'id': '37156fe3-c5b1-4ee6-812a-7b54ce57cbfb',
#   'deviceName': 'MD_05',
#   'profileName': 'MD-Device-MQTT-Profile',
#   'sourceName': 'MicrodustNodeStatus',
#   'origin': 1698807113034364892,
#   'readings': [{'id': '9b749f02-0eb9-43e3-a1ab-1e93c71ed678',
#     'origin': 1698807113034232686,
#     'deviceName': 'MD_05',
#     'resourceName': 'MicrodustNodeStatus',
#     'profileName': 'MD-Device-MQTT-Profile',
#     'valueType': 'Object',
#     'value': '',
#     'objectValue': {'device': {'data': [77, 68], 'type': 'Buffer'},
#      'device_id': '56cb21c217805117',
#      'error': 0,
#      'humidity': 81,
#      'len': '45',
#      'msgid': {'data': [48, 50], 'type': 'Buffer'},
#      'pm10': 31,
#      'pm25': 18,
#      'seqnum': '0001',
#      'temperature': 19.1,
#      'timestamp': '231101115142'}}]}}

# %%
res_payload = json_list2[999]["Payload"]
dec_res = base64.b64decode(res_payload)
dec_res = dec_res.decode("UTF-8")
str_test = dec_res.replace("'","\"")
json_data = json.loads(str_test)
json_data
# Out:
# {'apiVersion': 'v2',
#  'requestId': 'a6703857-3e75-47d6-80b3-a206a87605c3',
#  'event': {'apiVersion': 'v2',
#   'id': '60749104-414b-4c46-91f9-13cb373f1c0b',
#   'deviceName': 'MD_08',
#   'profileName': 'MD-Device-MQTT-Profile',
#   'sourceName': 'MicrodustNodeStatus',
#   'origin': 1698807904303275347,
#   'readings': [{'id': 'c19707fa-868b-4773-aad6-4bf8914ef0a5',
#     'origin': 1698807904303249044,
#     'deviceName': 'MD_08',
#     'resourceName': 'MicrodustNodeStatus',
#     'profileName': 'MD-Device-MQTT-Profile',
#     'valueType': 'Object',
#     'value': '',
#     'objectValue': {'device': {'data': [77, 68], 'type': 'Buffer'},
#      'device_id': '697d56637cc66b08',
#      'error': 0,
#      'humidity': 84,
#      'len': '45',
#      'msgid': {'data': [48, 50], 'type': 'Buffer'},
#      'pm10': 35,
#      'pm25': 18,
#      'seqnum': '0001',
#      'temperature': 20.6,
#      'timestamp': '231101120453'}}]}}

# %% [markdown]
# # 변수별 차분 계산

# %%
#절대값 차분
diff_humid = []
diff_pm10 = []
diff_pm25 = []
diff_temp = []

for i in range(len(humid)-1):
    diff_humid.append(abs(humid[i+1]-humid[i]))
    diff_pm10.append(abs(pm10[i+1]-pm10[i]))
    diff_pm25.append(abs(pm25[i+1]-pm25[i]))
    diff_temp.append(abs(temp[i+1]-temp[i]))

# %% [markdown]
# # 감소율을 위한 최적값 계산

# %%
while True :
    window_size = random.randint(1,100)
    step = random.randint(1,10)
    weight = random.uniform(0.1,0.3)

    humid_window = list(sliding_window(diff_humid,window_size,step))
    pm10_window = list(sliding_window(diff_pm10,window_size,step))
    pm25_window = list(sliding_window(diff_pm25,window_size,step))
    temp_window = list(sliding_window(diff_temp,window_size,step))

    avdf_humid = statistics.mean(humid_window[random.randint(1,len(humid_window)-1)])
    avdf_pm10 = statistics.mean(pm10_window[random.randint(1,len(pm10_window)-1)])
    avdf_pm25 = statistics.mean(pm25_window[random.randint(1,len(pm25_window)-1)])
    avdf_temp = statistics.mean(temp_window[random.randint(1,len(temp_window)-1)])

    cnt_val = []
    for i in range(len(diff_humid)):
        if diff_humid[i] < avdf_humid + weight and diff_pm10[i] < avdf_pm10 + weight and diff_pm25[i] < avdf_pm25 + weight and diff_temp[i] < avdf_temp + weight:
            cnt_val.append(i)

    
    if 100<len(cnt_val)<120:
        
        #print("윈도우 사이즈 : ", window_size)
        #print("스텝 사이즈 : ", step)
        #print("가중치 : ", weight)
        
        print("입력 트래픽 수 :", len(humid))
        print("출력 트래픽 수 : ", len(humid)-len(cnt_val))
        print("감소율 : ", round((len(humid)-(len(humid)-len(cnt_val)))/len(humid) * 100, 2), "%")
        break;
# Out:
# 입력 트래픽 수 : 1000
# 출력 트래픽 수 :  885
# 감소율 :  11.5 %

# %%
test = test.transpose()

# %%
len(humid_window)
# Out:
# 98

# %%
len(cnt_val)
# Out:
# 107
